# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()
reg.fit([[0, 0], [1, 1], [2, 2]], [0, 1, 2])
print(reg.coef_)
print(reg.intercept_)
# Out:
# [0.5 0.5]
# 1.1102230246251565e-16

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from palmerpenguins import load_penguins
df = load_penguins()

# %%
ade_fe_fl = df[(df['species'] == 'Adelie') & (df['sex'] == 'female')]['flipper_length_mm']
ade_fe_bm = df[(df['species'] == 'Adelie') & (df['sex'] == 'female')]['body_mass_g']
X = ade_fe_fl.to_frame()

reg.fit(X,ade_fe_bm) # predicting the weight from the length of flipper
print(reg.coef_)
print(reg.intercept_)
# Out:
# [12.65908373]
# 991.5290574707064
